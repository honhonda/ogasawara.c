# %% [markdown]
# <a href="https://colab.research.google.com/github/honhonda/ogasawara.c/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##レポート２

# %% [markdown]
# - 2342085 知久晃大

# %% [markdown]
# ##05

# %%
pip install japanize_matplotlib | tail -n 1

# %%
import japanize_matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, GridSearchCV, LeaveOneOut
from  sklearn.neighbors import KNeighborsRegressor
from statsmodels.stats.weightstats import CompareMeans, DescrStatsW
from sympy import *

# %%
data2 = sm.datasets.get_rdataset('cars', 'datasets').data
data2.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
tmp = pd.read_csv('https://www.data.jma.go.jp/cpdinfo/temp/list/csv/an_wld.csv', encoding='Shift_JIS')
print(tmp.head())
# Out:
#       年  世界全体   北半球   南半球
# 0  1891 -0.78 -0.88 -0.68
# 1  1892 -0.89 -1.00 -0.74
# 2  1893 -0.94 -1.06 -0.79
# 3  1894 -0.86 -0.93 -0.77
# 4  1895 -0.82 -0.95 -0.67

# %%
data3 = tmp[['年', '世界全体']]
data3.head()
# Out:
#       年  世界全体
# 0  1891 -0.78
# 1  1892 -0.89
# 2  1893 -0.94
# 3  1894 -0.86
# 4  1895 -0.82

# %%
X = data2[['speed']]
y = data2['dist']

model = KNeighborsRegressor()
model.fit(X, y)
# Out:
# KNeighborsRegressor()

# %%
x=data2['speed']
tmp=pd.DataFrame({'speed':np.linspace(x.min(), x.max(), 100)})
tmp['model']=model.predict(tmp)
pd.concat([data2, tmp]).plot(x='speed', style=['o','-']);

# %% [markdown]
# ##パラメータチューニング

# %% [markdown]
# - 課題 data2に対するK最近傍法で，K
# の値を1から15の間でチューニングせよ。検証はLOOCVで行い，性能指標はMSEとする。

# %%
x=data2[['speed']]
y=data2['dist']

params={'n_neighbors':range(1,16)}
search=GridSearchCV(KNeighborsRegressor(), params, scoring='neg_mean_squared_error')
search.fit(x,y)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(1, 16)},
#              scoring='neg_mean_squared_error')

# %% [markdown]
# - 課題　最良パラメータを採用したモデルの振る舞いを可視化せよ

# %%
model=search.best_estimator_
x=data2['speed']
tmp=pd.DataFrame({'speed':np.linspace(x.min(), x.max(), 100)})
tmp['model']=model.predict(tmp)

pd.concat([data2, tmp]).plot(x='speed', style=['o','-'])
# Out:
# <Axes: xlabel='speed'>

# %%
x=data3[['年']]
y=data3['世界全体']

model = KNeighborsRegressor()
model.fit(x, y)
# Out:
# KNeighborsRegressor()

# %%
x=data3['年']
tmp=pd.DataFrame({'年':np.linspace(x.min(), x.max(), 100)})
tmp['model']=model.predict(tmp)

pd.concat([data3, tmp]).plot(x='年', style=['o','-']);

# %% [markdown]
# - 課題　最良パラメータを採用したモデルのPRESS/n-------√を求めよ

# %%
(-cross_val_score(model, X, y, cv=LeaveOneOut(), scoring='neg_mean_squared_error')).mean()**0.5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5ebfb53a6e73> in <cell line: 1>()
# ----> 1 (-cross_val_score(model, X, y, cv=LeaveOneOut(), scoring='neg_mean_squared_error')).mean()**0.5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     682     scorer = check_scoring(estimator, scoring=scoring)
#     683
# ...

# %%
X = data2[['speed']]
y = data2['dist']

(-cross_val_score(model, X, y, cv=LeaveOneOut(), scoring='neg_mean_squared_error')).mean()**0.5
# Out:
# 16.07308308943869

# %% [markdown]
# ## 06 重回帰

# %%
# !pip install japanize_matplotlib | tail -n 1

# %%
import japanize_matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import metrics
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV, LeaveOneOut
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, PolynomialFeatures, StandardScaler
from sympy import *

def TRAIN_RMSE(model, X, y):
  model.fit(X, y)
  y_ = model.predict(X)
  return metrics.root_mean_squared_error(y, y_)

def CV_RMSE(model, X, y):
  return (-cross_val_score(model, X, y, cv=LeaveOneOut(), scoring='neg_mean_squared_error')).mean()**0.5

# %% [markdown]
# ## 2重回帰

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/taroyabuki/fromzero/master/data/wine.csv')
data1
# Out:
#     LPRICE2  WRAIN  DEGREES  HRAIN  TIME_SV
# 0  -0.99868    600  17.1167    160       31
# 1  -0.45440    690  16.7333     80       30
# 2  -0.80796    502  17.1500    130       28
# 3  -1.50926    420  16.1333    110       26
# 4  -1.71655    582  16.4167    187       25
# 5  -0.41800    485  17.4833    187       24
# 6  -1.97491    763  16.4167    290       23
# 7   0.00000    830  17.3333     38       22
# 8  -1.10572    697  16.3000     52       21
# 9  -1.78098    608  15.7167    155       20
# 10 -1.18435    402  17.2667     96       19
# 11 -2.24194    602  15.3667    267       18
# 12 -0.74943    819  16.5333     86       17
# 13 -1.65388    714  16.2333    118       16
# 14 -2.25018    610  16.2000    292       15
# 15 -2.14784    575  16.5500    244       14
# 16 -0.90544    622  16.6667     89       13
# 17 -1.30031    551  16.7667    112       12
# 18 -2.28879    536  14.9833    158       11
# 19 -1.85700    376  17.0667    123       10
# ...

# %% [markdown]
# - 課題　LPRICE2以外の変数を入力変数、LPRICE２を出力変数として、線形重回帰分析を行い、回帰係数の推定値を求めよ。訓練後に回帰係数の推定値を確認するコードを示す

# %%
import pandas as pd

data1 = pd.read_csv('https://raw.githubusercontent.com/taroyabuki/fromzero/master/data/wine.csv')
X = data1.drop(columns=['LPRICE2'])

X
# Out:
#     WRAIN  DEGREES  HRAIN  TIME_SV
# 0     600  17.1167    160       31
# 1     690  16.7333     80       30
# 2     502  17.1500    130       28
# 3     420  16.1333    110       26
# 4     582  16.4167    187       25
# 5     485  17.4833    187       24
# 6     763  16.4167    290       23
# 7     830  17.3333     38       22
# 8     697  16.3000     52       21
# 9     608  15.7167    155       20
# 10    402  17.2667     96       19
# 11    602  15.3667    267       18
# 12    819  16.5333     86       17
# 13    714  16.2333    118       16
# 14    610  16.2000    292       15
# 15    575  16.5500    244       14
# 16    622  16.6667     89       13
# 17    551  16.7667    112       12
# 18    536  14.9833    158       11
# 19    376  17.0667    123       10
# 20    574  16.3000    184        9
# 21    572  16.9500    171        8
# 22    418  17.6500    247        7
# 23    821  15.5833     87        6
# 24    763  15.8167     51        5
# 25    717  16.1667    122        4
# ...

# %%
y = data1.drop('LPRICE2', axis=1)
y
# Out:
#     WRAIN  DEGREES  HRAIN  TIME_SV
# 0     600  17.1167    160       31
# 1     690  16.7333     80       30
# 2     502  17.1500    130       28
# 3     420  16.1333    110       26
# 4     582  16.4167    187       25
# 5     485  17.4833    187       24
# 6     763  16.4167    290       23
# 7     830  17.3333     38       22
# 8     697  16.3000     52       21
# 9     608  15.7167    155       20
# 10    402  17.2667     96       19
# 11    602  15.3667    267       18
# 12    819  16.5333     86       17
# 13    714  16.2333    118       16
# 14    610  16.2000    292       15
# 15    575  16.5500    244       14
# 16    622  16.6667     89       13
# 17    551  16.7667    112       12
# 18    536  14.9833    158       11
# 19    376  17.0667    123       10
# 20    574  16.3000    184        9
# 21    572  16.9500    171        8
# 22    418  17.6500    247        7
# 23    821  15.5833     87        6
# 24    763  15.8167     51        5
# 25    717  16.1667    122        4
# ...

# %% [markdown]
# ## 2.1線形重回帰分析

# %%
model=LinearRegression()
model.fit(X,y)

print(model.intercept_,model.coef_)
# Out:
# [ 1.13686838e-13 -9.94759830e-14  3.12638804e-13  1.42108547e-14] [[ 1.00000000e+00 -6.06336240e-15 -2.14495382e-17 -5.28947912e-16]
#  [ 5.91504784e-17  1.00000000e+00  1.11022302e-16 -6.59194921e-17]
#  [ 3.94430624e-17 -2.45359288e-14  1.00000000e+00  5.03069808e-16]
#  [ 8.05803027e-18 -1.69655956e-15  1.04083409e-17  1.00000000e+00]]

# %%
pd.Series([model.intercept_] + list(model.coef_), index=(['const'] + list(X.columns)))
# Out:
# const      [1.1368683772161603e-13, -9.947598300641403e-1...
# WRAIN      [1.0, -6.063362401230326e-15, -2.1449538208663...
# DEGREES    [5.915047841710042e-17, 1.0000000000000029, 1....
# HRAIN      [3.944306237147362e-17, -2.453592884421596e-14...
# TIME_SV    [8.058030270222789e-18, -1.6965595595053173e-1...
# dtype: object

# %% [markdown]
# ## 2.1.3予測

# %% [markdown]
# - 課題 WRAIN，DEGREES，HRAIN，TIME_SVが，500，17，120，2のときの，LPRICE2を予測せよ．

# %%
test=pd.DataFrame([[500,17,120,2]],columns=X.columns)
test
# Out:
#    WRAIN  DEGREES  HRAIN  TIME_SV
# 0    500       17    120        2

# %%
model.predict(test)
# Out:
# array([[500.,  17., 120.,   2.]])

# %%
def TRAIN_RMSE(model, X, y):
  model.fit(X, y)
  return metrics.mean_squared_error(y, model.predict(X))**0.5

# %% [markdown]
# - 課題 K最近傍法のRMSE（訓練）と PRESS/n−−−−−−−−√
#  を求めよ．近傍の数は5（デフォルト）とする．

# %%
from sklearn.neighbors import KNeighborsRegressor

def TRAIN_RMSE(model, X, y):
  model.fit(X, y)
  return metrics.mean_squared_error(y, model.predict(X))**0.5


model = KNeighborsRegressor()
model.fit(X,y)
print(TRAIN_RMSE(model, X, y),CV_RMSE(model, X, y))
# Out:
# 21.846799913851775 28.772094360571746

# %% [markdown]
# ### 2.2標準化の練習

# %%
X = data1.drop(columns='LPRICE2')
y = data1['LPRICE2']

# %% [markdown]
# 課題 入力変数の箱ひげ図を描け

# %%
X.boxplot();

# %% [markdown]
# 課題 入力変数を標準化した結果の箱ひげ図を描け．

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
Z=ss.fit_transform(X)
pd.DataFrame(ss.transform(X),columns=X.columns).boxplot();

# %% [markdown]
# 課題 線形回帰分析は標準化の影響を受けないことを確かめよ

# %% [markdown]
# ※標準化する場合

# %%
from sklearn.pipeline import Pipeline
pipeline=Pipeline([
    ('ss',StandardScaler()),
    ('model',LinearRegression())
])

print(TRAIN_RMSE(pipeline, X, y),CV_RMSE(pipeline, X, y))
# Out:
# 0.258616662013062 0.32300426518411574

# %% [markdown]
# ※しない場合

# %%
pipeline=Pipeline([
    ('ss',StandardScaler()),
    ('ir',LinearRegression())
])

print(TRAIN_RMSE(pipeline, X, y),CV_RMSE(pipeline, X, y))
# Out:
# 0.258616662013062 0.32300426518411574

# %% [markdown]
# 課題 K最近傍法は標準化の影響を受けることを確かめよ．

# %%
pipeline=Pipeline([
    ('ss',StandardScaler()),
    ('knn',KNeighborsRegressor())
])

print(TRAIN_RMSE(pipeline, X, y),CV_RMSE(pipeline, X, y))

pipeline=Pipeline([
    ('knn',KNeighborsRegressor())
])

print(TRAIN_RMSE(pipeline, X, y),CV_RMSE(pipeline, X, y))
# Out:
# 0.34422210961787125 0.4322419422955243
# 0.5156777171587639 0.625582528426343

# %% [markdown]
# ### 2.3実践

# %%
data3 = pd.read_csv('https://github.com/asakura-data-science/introduction/raw/refs/heads/main/Chapter5/choco_ice.csv', encoding='sjis')
data3.head()
# Out:
#    日最高気温の平均(℃)  year  month  チョコレート【円/日】  アイスクリーム・シャーベット【円/日】  feb
# 0         17.0  2009     11    12.166667            13.400000    0
# 1         12.4  2009     12    15.032258            14.193548    0
# 2         11.0  2010      1    14.709677            11.677419    0
# 3          9.9  2010      2    40.071429            10.892857    1
# 4         13.2  2010      3    13.193548            12.354839    0

# %% [markdown]
# 入力しやすいように、ラベルを付け替える

# %%
data3.columns = ['temp', 'year', 'month', 'choco', 'ice', 'feb']
data3.head()
# Out:
#    temp  year  month      choco        ice  feb
# 0  17.0  2009     11  12.166667  13.400000    0
# 1  12.4  2009     12  15.032258  14.193548    0
# 2  11.0  2010      1  14.709677  11.677419    0
# 3   9.9  2010      2  40.071429  10.892857    1
# 4  13.2  2010      3  13.193548  12.354839    0

# %%
import seaborn as sns


sns.regplot(x='temp', y='choco', data=data3);

# %%
#パターン１
from sklearn.compose import ColumnTransformer
x=data3[['temp']]
y=data3['choco']

ct=ColumnTransformer([
 ('pt','passthrough',['temp'])])
pipeline=Pipeline([
  ('ct',ct),
  ('lr',LinearRegression())
])
print(TRAIN_RMSE(pipeline, x, y),CV_RMSE(pipeline, x, y))
# Out:
# 7.566113543214987 7.730294828739399

# %%
#パターン２
x=data3[['temp','feb']]
ct=ColumnTransformer([
 ('pt','passthrough',['temp','feb'])])
pipeline=Pipeline([
  ('ct',ct),
  ('lr',LinearRegression())
])
print(TRAIN_RMSE(pipeline, x, y),CV_RMSE(pipeline, x, y))
# Out:
# 2.8682514939163704 2.9814680202539443

# %%
#パターン3
X=data3[['month']]

ct=ColumnTransformer([
 ('pt','passthrough',['month'])])
pipeline=Pipeline([
  ('ct',ct),
  ('lr',LinearRegression())
])
print(TRAIN_RMSE(pipeline, X, y),CV_RMSE(pipeline, X, y))
# Out:
# 9.553396280313608 9.75411198099738

# %%
#パターン4
x=data3[['month']]
# Import OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer([
 ('ohe',OneHotEncoder(drop='first'),['month'])])
pipeline=Pipeline([
  ('ct',ct),
  ('lr',LinearRegression())
])
print(TRAIN_RMSE(pipeline, x, y),CV_RMSE(pipeline, x, y))
# Out:
# 2.6151103595593086 2.9140237187945504

# %% [markdown]
# ## 08 多値分類
#
# - 人工知能
#   - 機械学習
#     - 教師あり機械学習
#       - 回帰（数値の予測）
#         - 線形回帰分析
#         - K最近傍法
#       - 分類
#     - 教師なし機械学習（訓練に使えるデータがない）
#     - 強化学習（正解はないが教師データはある）
# - 統計学?
#   - 線形回帰分析（数値の予測というより、メカニズムの理解を目指す）
#
# データサイエンスは上のような学問の「データを扱う」という共通点に着目した的あたらしい分野

# %% [markdown]
# ### 実践

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from mlxtend.plotting import plot_decision_regions
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.model_selection import cross_val_score, GridSearchCV, LeaveOneOut
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from xgboost import XGBClassifier

# K分割交差検証
def score_cv(model, X, y, k=5):
  return cross_val_score(model, X, y, cv=k).mean()

# 一つ抜き交差検証（LOOCV）
def score_loocv(model, X, y):
  return cross_val_score(model, X, y, cv=LeaveOneOut()).mean()

# %%
data1 = sm.datasets.get_rdataset('iris', 'datasets').data
data1
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data1.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data1.groupby('Species').size()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# 分類木を作る

# %%
X = data1[['Petal.Length', 'Petal.Width']]
y = data1['Species']

model = DecisionTreeClassifier(max_depth=2, random_state=0)
model.fit(X, y);

# %%
# !pip install graphviz
import graphviz
from sklearn.tree import export_graphviz
dot = export_graphviz(
  decision_tree=model,
  out_file=None,              # ファイルに出力しない．
  feature_names=X.columns,    # 変数名
  class_names=model.classes_, # カテゴリ名
  filled=True)                # 色を塗る．

graphviz.Source(dot)

# %% [markdown]
# 課題 二つの変数（Sepal.LengthとSepal.Width）だけを入力変数とする場合の決定木（max_depth=2）を作り，描け．
#
# 参考：決定境界を可視化する

# %% [markdown]
# x=data1[['Sepal.Length','Sepal.Width

# %% [markdown]
# 課題 （四つの説明変数を使って）アヤメを分類する決定木（max_depth=3）を作り，描け．

# %%
X = data1.drop(columns=['Species'])
y = data1['Species']

model = DecisionTreeClassifier(max_depth=3, random_state=0)
model.fit(X, y);

dot = export_graphviz(
  decision_tree=model,
  out_file=None,              # ファイルに出力しない．
  feature_names=X.columns,    # 変数名
  class_names=model.classes_, # カテゴリ名
  filled=True)                # 色を塗る．

graphviz.Source(dot)

# %% [markdown]
# 課題 次のサンプルのSpeciesを予測せよ

# %%
test = pd.DataFrame([[5.0,3.5,1.5,0.5],[6.5,3.0,5.0,2.0]],columns=X.columns) # Adjust the data to match the number of columns in X.columns
test
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           5.0          3.5           1.5          0.5
# 1           6.5          3.0           5.0          2.0

# %%
model.predict(test)
# Out:
# array(['setosa', 'virginica'], dtype=object)

# %% [markdown]
# 課題 訓練データにモデルを適用し，混同行列を作れ

# %%
y_ = model.predict(X)
cm = confusion_matrix(y_true=y, y_pred=y_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues');
plt.show()

# %% [markdown]
# 課題 正解率（訓練）を求めよ．

# %%
(50+47+49)/150
# Out:
# 0.9733333333333334

# %%
model.score(X,y)
# Out:
# 0.9733333333333334

# %%
(y==y_).sum()
# Out:
# 146

# %% [markdown]
# 課題 正解率（LOOCV）を求めよ．

# %%
score_loocv(model, X, y)
# Out:
# 0.9466666666666667

# %% [markdown]
# 課題 木の深さが最大5の決定木を作り，描け．

# %%
X = data1.drop(columns=['Species'])
y = data1['Species']

model = DecisionTreeClassifier(max_depth=5, random_state=0)
model.fit(X, y);

dot = export_graphviz(
  decision_tree=model,
  out_file=None,              # ファイルに出力しない．
  feature_names=X.columns,    # 変数名
  class_names=model.classes_, # カテゴリ名
  filled=True)                # 色を塗る．

graphviz.Source(dot)

# %% [markdown]
# 課題 訓練データにモデルを適用し，混同行列を作れ．

# %%
y_ = model.predict(X)
cm = confusion_matrix(y_true=y, y_pred=y_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues');
plt.show()

# %% [markdown]
# 課題 正解率（訓練）と正解率（LOOCV）を求めよ．

# %%
model.score(X,y)
# Out:
# 1.0

# %%
score_loocv(model, X, y)
# Out:
# 0.9466666666666667

# %% [markdown]
# 課題 ランダムフォレストの正解率（訓練）と正解率（LOOCV）を求めよ．

# %%
model=RandomForestClassifier(random_state=0)
model.fit(X,y)

model.score(X,y)
# Out:
# 1.0

# %% [markdown]
# 課題 ランダムフォレストでの変数の重要度を求めて，可視化せよ．

# %%
score_loocv(model, X, y)
# Out:
# 0.96

# %% [markdown]
# ワインの化学分析の結果からクラスを予測する問題を解く

# %%
from sklearn.datasets import load_wine
data3 = load_wine()

X = data3.data
y = data3.target

tmp = pd.DataFrame(X, columns=data3.feature_names)
tmp['class'] = y
tmp.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  class
# ...

# %% [markdown]
# 課題 分類木とランダムフォレストの予測性能を，5分割交差検証で比較せよ．パラメータはデフォルトとすること

# %%
model=DecisionTreeClassifier(random_state=0)
model.fit(X,y)

print(model.score(X,y))
print(score_cv(model, X, y))
# Out:
# 1.0
# 0.8876190476190475

# %%
model=RandomForestClassifier(random_state=0)
model.fit(X,y)

print(model.score(X,y))
print(score_cv(model, X, y))
# Out:
# 1.0
# 0.9833333333333332

# %%
data4 = fetch_openml(name='car', version=1, as_frame=True).frame;
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:1030: UserWarning: Version 1 of dataset car is inactive, meaning that issues have been found in the dataset. Try using a newer version from this URL: https://api.openml.org/data/v1/download/21/car.arff
#   warn(

# %%
data4.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
for col in data4.columns:
  print(col)
  print(data4[col].unique())
  print()
# Out:
# buying
# ['vhigh', 'high', 'med', 'low']
# Categories (4, object): ['high', 'low', 'med', 'vhigh']
#
# maint
# ['vhigh', 'high', 'med', 'low']
# Categories (4, object): ['high', 'low', 'med', 'vhigh']
#
# doors
# ['2', '3', '4', '5more']
# Categories (4, object): ['2', '3', '4', '5more']
#
# persons
# ['2', '4', 'more']
# Categories (3, object): ['2', '4', 'more']
#
# lug_boot
# ['small', 'med', 'big']
# Categories (3, object): ['big', 'med', 'small']
#
# safety
# ['low', 'med', 'high']
# Categories (3, object): ['high', 'low', 'med']
#
# class
# ['unacc', 'acc', 'vgood', 'good']
# Categories (4, object): ['acc', 'good', 'unacc', 'vgood']

# %% [markdown]
# 課題 分類木とランダムフォレストの予測性能を，5分割交差検証で比較せよ．パラメータはデフォルトとすること．

# %%
x=data4.drop(columns=['class'])
y=data4['class']

pipeline = Pipeline([
  ('ohe', OneHotEncoder(drop='first')),
  ('model', DecisionTreeClassifier(max_depth=3, random_state=0))
])

pipeline.fit(x,y)
print(pipeline.score(x,y))
print(score_cv(pipeline, x, y))
# Out:
# 0.7916666666666666
# 0.6984686269581971

# %%
x=data4.drop(columns=['class'])
y=data4['class']

pipeline = Pipeline([
  ('ohe', OneHotEncoder(drop='first')),
  ('model', RandomForestClassifier(max_depth=3, random_state=0))
])

pipeline.fit(x,y)
print(pipeline.score(x,y))
print(score_cv(pipeline, x, y))
# Out:
# 0.7002314814814815
# 0.7037111502052442

# %%
X = data4.drop(columns=['class'])
y = data4['class'].map({'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3})
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1723    2
# 1724    3
# 1725    0
# 1726    2
# 1727    3
# Name: class, Length: 1728, dtype: category
# Categories (4, int64): [1, 2, 0, 3]

# %% [markdown]
# 課題 次のコードの実行結果を調べよ。
# 「vhighのようなラベルを数値に変換できない」というエラーになる.

# %%
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-d2f306feeedb> in <cell line: 2>()
#       1 model = DecisionTreeClassifier()
# ----> 2 model.fit(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1017         """
#    1018
# -> 1019         super()._fit(
#    1020             X,
#    1021             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     250             )
# ...

# %% [markdown]
# 課題 OneHotEncoderで質的変数を数値に変換して，決定木を訓練し，5分割交差検証でで予測性能を見積もれ。

# %%
pipeline = Pipeline([
  ('ohe', OneHotEncoder(handle_unknown='ignore')),
  ('model', DecisionTreeClassifier(random_state=0))
])

print(score_cv(pipeline, X, y))
# Out:
# 0.7494563123062746

# %% [markdown]
# 課題 RandomForestClassifierとXGBClassifierの予測性能を見積もれ

# %%
pipeline = Pipeline([
  ('ohe', OneHotEncoder(handle_unknown='ignore')),
  ('model', RandomForestClassifier(random_state=0))
])

print(score_cv(pipeline, X, y))
# Out:
# 0.7685917734774231

# %% [markdown]
# ## 09 2値分類

# %%
import graphviz
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from xgboost import XGBClassifier

# %%
y       = np.array([  0,   1,   1,   0,   1,   0,    1,   0,   0,   1])
y_score = np.array([0.7, 0.8, 0.3, 0.4, 0.9, 0.6, 0.99, 0.1, 0.2, 0.5])

# %% [markdown]
# 課題 検査結果が0.5以上のものを陽性とする場合の，混同行列を求めよ。

# %%
y_=(y_score>=0.5).astype(int)
y_
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 0, 0, 1])

# %%
y_=np.array([1 if p>=0.5 else 0 for p in y_score])
y_
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 0, 0, 1])

# %%
ConfusionMatrixDisplay.from_predictions(y_true=y, y_pred=y_,cmap='Blues');

# %%
print(classification_report(y_true=y, y_pred=y_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67         5
#            1       0.67      0.80      0.73         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10

# %% [markdown]
# 課題 classification_report(y_true=y, y_pred=y_)の結果について説明せよ（macro avgとweighted avgは対象外）。

# %% [markdown]
# 1(陽性)について説明する0(陰性)は別
# - precision(精度)は1だと予想したもので、本当に1だったものの割合
# - recall（再現率）は、本当に1だったもので、1度と予測できるものの割合
# - accuracy(正解率)は、全体で正しく予測できたものの割合
# - f1-score(F1スコア)は、精度と再現率の調和平均

# %% [markdown]
# 課題 検査結果が0.9以上のものを陽性とする場合の，精度と再現率を求めよ。

# %%
y_=(y_score>=0.9).astype(int)
print(classification_report(y_true=y, y_pred=y_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       1.00      0.40      0.57         5
#
#     accuracy                           0.70        10
#    macro avg       0.81      0.70      0.67        10
# weighted avg       0.81      0.70      0.67        10

# %% [markdown]
# 課題 検査結果が0.2以上のものを陽性とする場合の，精度と再現率を求めよ。

# %%
y_=(y_score>=0.2).astype(int)
print(classification_report(y_true=y, y_pred=y_))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.33         5
#            1       0.56      1.00      0.71         5
#
#     accuracy                           0.60        10
#    macro avg       0.78      0.60      0.52        10
# weighted avg       0.78      0.60      0.52        10

# %% [markdown]
# 課題 再現率と精度の関係を2次元平面上の曲線で可視化せよ。

# %%
PrecisionRecallDisplay.from_predictions(y_true=y, y_pred=y_score);

# %% [markdown]
# 課題 上の課題の曲線の下の部分の面積（AUC, Area Under the Curve）を求めよ。

# %%
average_precision_score(y_true=y, y_score=y_score)
# Out:
# 0.8583333333333332

# %% [markdown]
# ### 実践

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from xgboost import XGBClassifier

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/taroyabuki/fromzero/master/data/titanic.csv')
data1.head()
# Out:
#   Class   Sex    Age Survived
# 0   1st  Male  Child      Yes
# 1   1st  Male  Child      Yes
# 2   1st  Male  Child      Yes
# 3   1st  Male  Child      Yes
# 4   1st  Male  Child      Yes

# %%
for col in data1.columns:
  print(f"--- Column: {col} ---")
  print(data1[col].value_counts(dropna=False))
  print("\n")
# Out:
# --- Column: Class ---
# Class
# Crew    885
# 3rd     706
# 1st     325
# 2nd     285
# Name: count, dtype: int64
#
#
# --- Column: Sex ---
# Sex
# Male      1731
# Female     470
# Name: count, dtype: int64
#
#
# --- Column: Age ---
# Age
# Adult    2092
# Child     109
# Name: count, dtype: int64
#
#
# --- Column: Survived ---
# Survived
# No     1490
# Yes     711
# Name: count, dtype: int64

# %% [markdown]
# 課題 DecisionTreeClassifier(random_state=0)で生死を予測する場合の正解率を，5分割交差検証で見積もれ。

# %%
x=data1.drop(columns=['Survived'])
y=data1['Survived']

pipeline = Pipeline([
  ('ohn', OneHotEncoder(handle_unknown='ignore')),
  ('tree', DecisionTreeClassifier(random_state=0))
])

print(score_cv(pipeline, x, y))
# Out:
# 0.6616037930323644

# %%
pipeline.fit(x, y); # Change X to x

ohe = pipeline.named_steps['ohn']
model = pipeline.named_steps['tree']

plot_tree(decision_tree=model,
          feature_names=ohe.get_feature_names_out(),
          class_names=model.classes_,
          filled=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 課題 データを訓練データとテストデータに9:1で分けて，訓練データでDecisionTreeClassifier(random_state=0)を訓練し，テストデータでの混同行列を作れ。

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

pipeline.fit(X_train, y_train);

ConfusionMatrixDisplay.from_estimator(pipeline, X_test, y_test, cmap='Blues');

# %% [markdown]
# 課題 テストデータでの精度・再現率・正解率を求めよ

# %%
y_=pipeline.predict(X_test)
print(classification_report(y_true=y_test, y_pred=y_))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.75      0.98      0.85       288
#          Yes       0.90      0.39      0.55       153
#
#     accuracy                           0.77       441
#    macro avg       0.82      0.68      0.70       441
# weighted avg       0.80      0.77      0.74       441

# %%
60/(60+7)
# Out:
# 0.8955223880597015

# %% [markdown]
# 課題 テストデータでの再現率と精度の関係を2次元平面上の曲線で可視化し，AUCを求めよ。

# %%
PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)

# %% [markdown]
# ## 10 手書き数字の分類

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from tensorflow.keras.activations import relu
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
data1 = load_digits()
print(data1.data.shape)
# Out:
# (1797, 64)

# %%
data1.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
data1.data[0].reshape(8, -1)
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(data1.data[0].reshape(8, -1), cmap='gray');

# %%
for i in range(10):
  plt.subplot(2, 5, i + 1);
  plt.imshow(data1.images[i], cmap='gray');
  plt.title(data1.target[i]);
  plt.axis('off');
plt.tight_layout();

# %%
X = data1.data
y = data1.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# 課題 DecisionTreeClassifier(random_state=0)を訓練し，テストデータにおける混同行列を作れ．

# %%
model=DecisionTreeClassifier(random_state=0)
model.fit(X_train, y_train)

ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, cmap='Blues');

# %% [markdown]
# 課題 テストデータにおける正解率を求めよ．

# %%
print(model.score(X_test, y_test))
# Out:
# 0.8472222222222222

# %%
y_=model.predict(X_test)
(y_==y_test).mean()
# Out:
# 0.8472222222222222

# %% [markdown]
# 課題 RandomForestClassifier(random_state=0)を訓練し，テストデータにおける正解率を求めよ．

# %%
model=RandomForestClassifier(random_state=0)
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.9694444444444444
